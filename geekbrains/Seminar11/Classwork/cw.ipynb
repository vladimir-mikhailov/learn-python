# %% [markdown]
# ## Семинар 11. Jupyter Notebook и несколько слов об аналитике

# %% [markdown]
# ### f(x) = 5x^2 + 10x - 30

# %% [markdown]
# 1. Определить корни

# %%
from decimal import Decimal, getcontext
from sympy import *
getcontext().prec = 20
# from sympy.abc import x
x = Symbol("x", real=True)
f = Function('f')
# Корни
f = collect((5*x ** 2 + 10*x - 30), x)
roots = solve(Eq(f, 0), x)
print(f'Корень 1: {roots[0]}', f'Корень 2: {roots[1]}', sep='\n')
# Out:
# Корень 1: -1 + sqrt(7)
# Корень 2: -sqrt(7) - 1

# %% [markdown]
# 2. Найти интервалы, на которых функция возрастает

# %%
df = f.diff(x)
solve(df > 0)
# Out:
# -1 < x

# %% [markdown]
# 3. Найти интервалы, на которых функция убывает

# %%
solve(df < 0)
# Out:
# x < -1

# %% [markdown]
# 4. Построить график

# %%
from sympy.plotting import plot
plot(f, (x, -10, 10))

# %% [markdown]
# 5. Вычислить низину

# %%
df_x = solve(df, x)[0]
print('Y =', f.subs(x, df_x), f' X = {df_x}')
# Out:
# Y = -35  X = -1

# %% [markdown]
# 6. Определить промежутки, на котором f > 0

# %%
solve(f > 0)
# Out:
# (-1 + sqrt(7) < x) | (x < -sqrt(7) - 1)

# %% [markdown]
# 7. Определить промежутки, на котором f < 0

# %%
solve(f < 0)
# Out:
# (x < -1 + sqrt(7)) & (-sqrt(7) - 1 < x)
